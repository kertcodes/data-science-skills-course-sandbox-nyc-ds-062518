# %% [markdown]
# # Pair Programming Environment

# %%
for n in range (1,101):
    print (n)
    if n%2 is 1: 
        print ('odd')
        if n%5 is 0:
            print ('high five!')
    elif n%2 is 0 and n%7 is 0:
        print ('is divisible by 14')
    if n>30 and n<45 and n%8 is 0:
        print ('this happens twice!')
# Out:
# 1
# odd
# 2
# 3
# odd
# 4
# 5
# odd
# high five!
# 6
# 7
# odd
# 8
# 9
# odd
# 10
# 11
# odd
# 12
# 13
# odd
# 14
# is divisible by 14
# 15
# odd
# high five!
# 16
# 17
# odd
# 18
# 19
# odd
# 20
# 21
# odd
# 22
# 23
# odd
# 24
# 25
# odd
# high five!
# 26
# 27
# odd
# 28
# is divisible by 14
# 29
# odd
# 30
# 31
# odd
# 32
# this happens twice!
# 33
# odd
# 34
# 35
# odd
# high five!
# 36
# 37
# odd
# 38
# 39
# odd
# 40
# this happens twice!
# 41
# odd
# 42
# is divisible by 14
# 43
# odd
# 44
# 45
# odd
# high five!
# 46
# 47
# odd
# 48
# 49
# odd
# 50
# 51
# odd
# 52
# 53
# odd
# 54
# 55
# odd
# high five!
# 56
# is divisible by 14
# 57
# odd
# 58
# 59
# odd
# 60
# 61
# odd
# 62
# 63
# odd
# 64
# 65
# odd
# high five!
# 66
# 67
# odd
# 68
# 69
# odd
# 70
# is divisible by 14
# 71
# odd
# 72
# 73
# odd
# 74
# 75
# odd
# high five!
# 76
# 77
# odd
# 78
# 79
# odd
# 80
# 81
# odd
# 82
# 83
# odd
# 84
# is divisible by 14
# 85
# odd
# high five!
# 86
# 87
# odd
# 88
# 89
# odd
# 90
# 91
# odd
# 92
# 93
# odd
# 94
# 95
# odd
# high five!
# 96
# 97
# odd
# 98
# is divisible by 14
# 99
# odd
# 100

# %%
11%2
# Out:
# 1

# %%
if -10: 
    print ('executed')
# Out:
# executed
